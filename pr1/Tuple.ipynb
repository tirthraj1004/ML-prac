# %%
tpl = ("abc","xyz", "qwe", "abc")
tpl
# Out:
# ('abc', 'xyz', 'qwe', 'abc')

# %% [markdown]
# Tuple is ordered

# %%
for x in range(len(tpl)):
  print( "<" + str(x) +">" +  tpl[x])
# Out:
# <0>abc
# <1>xyz
# <2>qwe
# <3>abc

# %% [markdown]
# Tuple is unchangeable

# %%
# tpl[0] = "ijk"

# %% [markdown]
# Tuple with one element

# %%
tpl2 = (1)
print(type(tpl2))
tpl2 = (1,)
print(type(tpl2))
# Out:
# <class 'int'>
# <class 'tuple'>

# %% [markdown]
# Nested Tuple

# %%
tpl3 = (tpl, tpl2, tuple((1,2,3,4,5)) )
tpl3
# Out:
# (('abc', 'xyz', 'qwe', 'abc'), (1,), (1, 2, 3, 4, 5))
