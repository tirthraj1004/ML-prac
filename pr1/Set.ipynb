# %% [markdown]
# Set have no duplicate element and is undordered

# %%
set1 = { "ABC", 10, True, 1.1, 10 }
print(set1)
# Out:
# {'ABC', 10, 1.1, True}

# %% [markdown]
# Set is unchangeable

# %%
# set[1]

# %% [markdown]
# Set can have multiple data type

# %%
print(type(set1))
for x in set1:
  print(str(x)+ ": " + str(type(x)))
# Out:
# <class 'set'>
# ABC: <class 'str'>
# 10: <class 'int'>
# 1.1: <class 'float'>
# True: <class 'bool'>

# %% [markdown]
# Set Operations

# %%
# Adding
set1.add("X")
set1.add(False)
set1
# Out:
# {1.1, 10, 'ABC', False, True, 'X'}

# %%
# Union
set2 = { 1,2,3,4,6,10,8,0 }
print("set1: "+ str(set1))
print("set2: "+ str(set2))

set3 = set1 | set2
print("set3: "+ str(set3))
# Out:
# set1: {False, 1.1, True, 'X', 10, 'ABC'}
# set2: {0, 1, 2, 3, 4, 6, 8, 10}
# set3: {False, 1.1, True, 2, 3, 4, 6, 'X', 8, 10, 'ABC'}

# %%
# Intersection
set3 = set3 & set1 
print("set3: "+ str(set3))
# Out:
# set3: {False, 1.1, True, 'X', 10, 'ABC'}

# %%
# Difference
set4 = set3 - {False, True}
print("set4: "+ str(set4))
# Out:
# set4: {'X', 1.1, 10, 'ABC'}

# %%
# Clear data
set1.clear()
set2.clear()
set3.clear()


print(set1)
print(set2)
print(set3)
print(set4)
# Out:
# set()
# set()
# set()
# {'X', 1.1, 10, 'ABC'}
